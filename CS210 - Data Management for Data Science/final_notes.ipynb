# %% [raw]
# NUMPY
# ---------------------------------------------------------------------------------------
# np.nan
# np.inf
#
# np.array() -> create n-dimensional array from argument (usually list)
# np.zeros() -> create n-dimensional array with all elements initialized to 0 from argument (single
#     number or tuple)
# np.ones()  -> create n-dimensional array with all elements initialized to 1 from argument (single
#     number or tuple)
# np.empty() -> create n-dimensional array with all elements initialized to empty (no particular
#     value)
# np.zeros_like()
# np.ones_like()
# np.empty_like()
# np.eye() -> Identity matrix (square matrix, only one integer argument for dimension)
# np.arange()
# np.isnan() -> np.nan (data type)
# np.power([ndarray_name], x) -> raise each element in ndarray to the x power
# np.exp()    -> compute e^x for each x in ndarray
# np.square() -> square each element in ndarray
# np.sqrt()   -> sqrt each element in ndarray
# np.abs()    -> absolute value each element in ndarray
# np.fabs()   -> (float) absolute value each element in ndarray
# np.ceil()   -> ceiling each element in ndarray
# np.floor()  -> floor each element in ndarray
# np.rint()   -> round each element in ndarray to nearest integer
# np.maximum()
# np.max() (not binary universal functino (ufunc), second argument for max is 'axis' or 'dimension')
# np.fmax() (ignores nan values)
# np.greater()
# np.random.randint(x, y) -> random integer from x (inclusive) to y (exclusive)
# np.random.random(x, y)
# np.random.choice()
# np.random.shuffle()
# np.random.permutation() (returns a new array, original is untouched)
# np.max()
# np.cumsum()
# np.argmin()
# np.unique() (sorted list of unique values)
# np.sort() (doesn't change the original array)
# np.argsort() (positions of sorted values)
# np.where()
# np.dot() -> matrix multiplication
# --------------------------------------------------------------------------------------------------
# [ndarray_name].dtype -> data type of n-dimensional array
# [ndarray_name].shape -> dimensions of n-dimensional array
# 	n = 1 -> ([rows], )
# 	n = 2 -> ([rows], [columns], )
# [ndarray_name].ndim  -> number of rows of n-dimensional array
# [ndarray_name].T -> transpose (does not modify original array)
# [ndarray_name].transpose() -> transpose alternative (does not modify original array)
# [ndarray_name].reshape()
# [ndarray_name].any()
# [ndarray_name].all()
# [ndarray_name].max()
# [ndarray_name].min()
# [ndarray_name].mean() ->
#     (axis=1 -> mean of column values for each row)
# 	(axis=0 -> mean of row values for each column)
# [ndarray_name].sum()
# [ndarray_name].std()
# [ndarray_name].cumsum()
# [ndarray_name].argmin() (index of minimum value)
# [ndarray_name].argmax() (index of maximum value)
# [ndarray_name].sort()    (ndarray sort method changes the array)
# [ndarray_name].argsort() (ndarray argsort method does not change original array)
# [ndarray_name].astype() -> always creates a new array, leaving original untouched
# [ndarray_name].copy() -> explicit copy of slice, not a view
# --------------------------------------------------------------------------------------------------
# NOTES:
# - An array slice is a "view" (not copy) on original array. If you modify a slice, the
# 	original array is modified!!
# - Slicing by column gives a COPY, not a view
# - However, slicing by row gives a VIEW, not a copy
# - Slicing with boolean filtering gets a COPY, not a view

# %% [raw]
# PANDAS
# --------------------------------------------------------------------------------------------------
# pd.cut()
# --------------------------------------------------------------------------------------------------
# [Series_name] = Series()
# [Series_name].values -> has a .dtype as well
# [Series_name].index  -> has a .dtype as well
# [Series.name].name
# [Series_name].index.name
# [Series_name].columns
# [Series_name].isnull()
# [Series_name].notnull()
# [Series_name].dropna([inplace=True]) (returns new Series, original is unchanged, unless inplace)
# [Series_name].reset_index()
# [Series_name].median()
# [Series_name].value_counts()
# [Series_name].unique()
# --------------------------------------------------------------------------------------------------
# [DataFrame_name] = DataFrame(, [columns=["a","b","c"]])
#     If you give a column name that's not a key in the dictionary, you get NaN's (like Series
#     index)
# [DataFrame_name].shape -> rows and columns as tuple (r, c)
# [DataFrame_name].index
# [DataFrame_name].columns
# [DataFrame_name].values
# [DataFrame_name].loc[] -> Row indexing by position (end value of range of rows is INCLUSIVE!)
# [DataFrame_name].iloc  -> Only integer indexing no column name like 'state'
# [DataFrame_name].apply(roundfn)  # each column is sent in as an argument; axis=1 -> row one by one
# [DataFrame_name].applymap() -> each item is treated like an ndarray, so cumulative sum is
#     trivially done on a single item
# [DataFrame_name].iterrows() -> iterate rows
# [DataFrame_name].iteritems()
# [DataFrame_name].groupby()
# [DataFrame_name].value_counts()
# [DataFrame_name].max()
# [DataFrame_name].drop() -> drop rows
# [DataFrame_name].info() -> non-null count and data type
# [DataFrame_name].describe() -> descriptive statistical stuff
# [DataFrame_name].T -> transpose (does not change the original dataframe, so you will need to
#     reassign if you want original to be updated)
# [DataFrame_name].head()
# [DataFrame_name].tail()
# --------------------------------------------------------------------------------------------------
# NOTES:
# - Indexes common to the argument index (univs) and the udict index are kept with their udict values, but for any index in univs that is not in udict, the value is NaN. Also, note that dtype has changed from int to float because of the NaN
# - Unlike Series, DataFrame does not have a .name attribute
# - When creating a DataFrame from nested dictionaries, the outer keys will be column names, and the inner will be indexes; indexes will be lined up, and NaN's will be used to fill missing values
# - In the above, the column names don't match any of the keys of popdat2, so the resulting dataframe has columns named AZ and VA, but no values; So this is similar to creating a Series out of a dictionary where an index is given, with only some labels matching the dictionary keys
# - Name of a column Series is simply the column name
# - Changing column names afterward is like assigning new names, not rearranging!
# - Row of  aDataFrame is a Series
# - Del operation to delete columns
# - Note above that an index can be converted to a list with the tolist method

# %% [raw]
# SQL
# --------------------------------------------------------------------------------------------------
# count(*)
# distinct()
# count(distinct())
